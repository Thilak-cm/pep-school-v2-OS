# %%
import pandas as pd

# Read the Excel file
educator_data = pd.read_excel('data/raw/Educator-Data.xlsx')

# Display the first few rows of the dataframe
educator_data.head(10)
# Out:
#   Location1   Location2                              Classroom/Environment  \
# 0       HSR         NaN                                          All Stars
# 1       HSR         NaN                                          All Stars
# 2       HSR         NaN                                          All Stars
# 3       HSR         NaN                                          All Stars
# 4       HSR         NaN                                          All Stars
# 5       HSR         NaN                                          All Stars
# 6       HSR         NaN                                          All Stars
# 7       HSR  Whitefield  HSR - All Stars/Power/Amazing/Plumeria/Perinwi...
# 8       HSR  Whitefield  HSR - All Stars/Power/Amazing/Plumeria/Perinwi...
# 9       HSR  Whitefield  HSR - All Stars/Power/Amazing\nWhitefield - El...
#
#            Educator Name          Educator Email ID
# 0             Gayathri V  gayathriv@pepschoolv2.com
# ...

# %%
educator_data['Classroom/Environment']
# Out:
# 0                                             All Stars
# 1                                             All Stars
# 2                                             All Stars
# 3                                             All Stars
# 4                                             All Stars
# 5                                             All Stars
# 6                                             All Stars
# 7     HSR - All Stars/Power/Amazing/Plumeria/Perinwi...
# 8     HSR - All Stars/Power/Amazing/Plumeria/Perinwi...
# 9     HSR - All Stars/Power/Amazing\nWhitefield - El...
# 10                                                Power
# 11                                                Power
# 12                                                Power
# 13                                              Amazing
# 14                                              Amazing
# 15                                              Amazing
# 16                                        Amazing/Power
# ...

# %%
# Export the dataframe to an Excel file
educator_data.to_excel('data/processed/educators_list.xlsx', index=False)
